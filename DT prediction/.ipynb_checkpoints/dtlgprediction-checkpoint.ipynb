# %%
import json
import re
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# '/home/d19125691/Experiments/Experiments/KGDTLG/git/DT prediction'

# %%
with open("./inputs/input8.json") as f: #1. change path here
    data = json.loads(f.read())

# %%
#url regular expression
urlRE = re.compile(r"(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'\".,<>?«»“”‘’]))")

# %%
#accessing nested
#1st JSON object
def accessJSON(data):
    global c
    for key,value in data.items():
        if(type(value)==type(str())  or type(value)==type(int())):
            stack.append(key)
            stack.append(value)
            if(key.lower()=="dt"):
                i=stack.pop()
                if(i.lower()=="int" or i.lower() == "dec" or i.lower() =="str" or i.lower()=="bool" or i.lower() == "integer" or i.lower() =="decimal"  or i.lower() =="string" or i.lower()=="boolean"):
                    if(i.lower()=="int" or i.lower()=="integer"):
                        i="xsd:integer"
                    elif(i.lower()=="dec" or i.lower() == "decimal"):
                        i="xsd:decimal"
                    elif(i.lower()=="bool" or i.lower() == "boolean"):
                        i="xsd:boolean"
                    else:
                        i="xsd:string"
                elif(re.search(urlRE,i.lower())):
                        res = re.findall(r'#',i) 
                        i="xsd:"+i[(i.index('#')+1):]
                stack.append(i)

        if type(value) == type(dict()):
            accessJSON(value)
        elif type(value) == type(list()):
            c=c+1
            if(c==2):
                break
            for val in value:
                if type(val) == type(str()):
                    pass
                elif type(val) == type(list()):
                    pass
                else:
                    accessJSON(val)

# %%
def seperatekeyvalues(stackelements):
    keys = []
    values = []

    for i in range(len(stackelements)):
        if(i%2==0):
            keys.append(stackelements[i])
        else:
            values.append(stackelements[i])
    return keys, values

# %%
def comparekeys(w1,w2):
    if(w1==w2):
        return True
    else:
        return False

# %%
def findingrowscolumns(keys):
    start=''
    ei=0
    count = 0
    for i in range(len(keys)):
        if(start==''):
            start=keys[i]
            si=i
        elif(keys[i]==start):
            end=keys[i-1]
            ei=i-1
            break   

    j=0
    count = 0
    for i in range(len(keys)):
        if(j >= len(keys)):
            break
        for k in range(ei+1):
            if(comparekeys(keys[k],keys[k+ei+1])==False):
                print("Keys are not of same length")
        j=j+ei+1
        count=count+1
    return count, (ei+1)

# %%
def writingintoFile(fileName, rows, column,keys, values):
    a=np.array(values).reshape(rows, column)
   
    # convert array into dataframe 
    DF = pd.DataFrame(a, columns=keys[0:column]) 
    DF.to_csv(fileName,index = False)

# %%
def accessJSONLT(data):
    global c
    for key,value in data.items():       
        if(type(value) == type(str()) and c==2):
            stackLG.append(key)
            stackLG.append(value)
        if type(value) == type(dict()):
            accessJSONLT(value)
        elif type(value) == type(list()):
            c=c+1
            if(c == 2):
                if(key.lower()!="languages"):
                    print("Error! Required language tag here!")
            for val in value:
                if type(val) == type(str()):
                    pass
                elif type(val) == type(list()):
                    pass
                else:
                    accessJSONLT(val)

# %%
stack=[]
c=0
accessJSON(data) #preprocess the datatype to required format
k,v=seperatekeyvalues(stack)
print(k,v)
rows,columns=findingrowscolumns(k)
writingintoFile("data1.csv", rows, columns, k, v)   #writes datatype modified column to file

flag=0
stackLG=[]
c=0
accessJSONLT(data)
if(stackLG):
    print("YAYA")
    k,v=seperatekeyvalues(stackLG)
    rows,columns=findingrowscolumns(k)
    writingintoFile("data1.csv", rows, columns, k, v)   #writes language tags to another file
    flag=1
# Out:
# ['firstname', 'lastname', 'lang', 'num', 'dt', 'firstname', 'lastname', 'lang', 'num', 'dt'] ['John', 'Doe', 'English', 3, 'xsd:integer', 'Jane', 'Smith', 'French', '3.14', 'xsd:decimal']

# %%
print(k,v)
# Out:
# ['firstname', 'lastname', 'lang', 'num', 'dt', 'firstname', 'lastname', 'lang', 'num', 'dt'] ['John', 'Doe', 'English', 3, 'xsd:integer', 'Jane', 'Smith', 'French', '3.14', 'xsd:decimal']

# %%
df1 = pd.read_csv("data1.csv")
header1=df1.columns.tolist()

if(flag==1):
    df2 = pd.read_csv("data2.csv")
    header2=df2.columns.tolist()

    count=0
    matchedHeader = []
    nextHeader = []

    for i in header1:
        for j in range(len(header2)):
            if(i==header2[j]):
                matchedHeader.append(i)
                count=count+1
                nextHeader.append(header2[j+1])
            if(count>=2):
                break

    res = df1.merge(df2, how='inner', left_on=[matchedHeader[0]], right_on=[matchedHeader[0]])
    print("from if",res)
else:
    res = df1
    print("from else\n",res)
# Out:
# from else
#    firstname lastname     lang   num           dt
# 0      John      Doe  English  3.00  xsd:integer
# 1      Jane    Smith   French  3.14  xsd:decimal

# %%
res.columns.tolist()
# Out:
# ['firstname', 'lastname', 'lang', 'num', 'dt']

# %%
lTags = pd.read_csv("ltgs.csv")

header = res.columns.tolist()

langColumn = None  # Initialize the variable

for col in header:
    if col == "lang":
        langColumn = "lang"
        break
else:  
    langColumn = "language"

languagePresent=res[[langColumn]].squeeze()
print(languagePresent)
langNew = []

for i in range(len(languagePresent)):
    for j in range(len(lTags)):
        lp=str(languagePresent[i])
        if(str(lTags.loc[j,"Language"]).lower() == lp.lower()):
            languagePresent[i] = (lTags.loc[j,"tag"])
print(languagePresent)
res[[langColumn]]=languagePresent
# Out:
# 0    English
# 1     French
# Name: lang, dtype: object
# 0    en
# 1    fr
# Name: lang, dtype: object

# %%
print(res)
# Out:
#   firstname lastname lang   num           dt
# 0      John      Doe   en  3.00  xsd:integer
# 1      Jane    Smith   fr  3.14  xsd:decimal

# %%
res.to_csv("./inputs/input8.csv", index=False)
